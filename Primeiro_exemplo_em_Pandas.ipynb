# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorGFL/CursodeExtens-opythonpandas/blob/main/Primeiro_exemplo_em_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Meu primeiro exemplo de manipulação de dados usando Phyton Pandas**
#
# AUTOR: Victor Gabriel Ferreira Leite
#
# DATA: 06/02/2023

# %%
#Importando biblioteca pandas no python
import pandas as pd

combustíveis_df = pd.read_csv("ca-2021-02.xlsx - ca-2021-02.csv")

print (combustíveis_df)

display(combustíveis_df)
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  NE             AL  ARAPIRACA
# 1                  NE             AL  ARAPIRACA
# 2                  NE             AL  ARAPIRACA
# 3                  NE             AL  ARAPIRACA
# 4                  NE             AL  ARAPIRACA
# ...               ...            ...        ...
# 168404             NE             BA     JEQUIE
# 168405             SE             MG  ITUIUTABA
# 168406             SE             MG  ITUIUTABA
# 168407             SE             MG  ITUIUTABA
# 168408             SE             MG  ITUIUTABA
#
#                                            Revenda      CNPJ da Revenda  \
# 0                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 1                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 2                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 3                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# ...

# %%
#Outra maneira de importar a biblioteca em lugares que não vem instalado
# !pip install pandas
